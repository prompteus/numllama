# %%
import pandas as pd
# import statsmodels.formula.api as smf
import seaborn as sns

sns.set_style("whitegrid")
sns.set_theme(rc={
    "axes.facecolor": "white",     # axes (plot area)
    "figure.facecolor": "white",   # figure (canvas)
    "grid.color": "0.9",            # light gray grid
    "figure.figsize": (3, 3)
})

# %%
# llama 3b-add

df = pd.read_csv('logs/model_vs_probes_preds_llama3b_add_220925.csv')
cols = [col for col in df.columns if 'probe' in col]
for col in cols:
    df[col] = abs(df[col] - df['labels'])

df['Correct result'] =  df['model_predictions'] == df['labels']
df[['Correct result'] + cols]

ax = sns.lineplot(
    data=(
        df[['Correct result'] + cols]
        .groupby('Correct result')
        .mean()
        .rename(columns={col: int(col[len('probe_l'):]) for col in cols})
        .reset_index()
        .melt(id_vars=['Correct result'], var_name='layer', value_name='Absolute error')
    ),
    x='layer',
    y='Absolute error',
    hue='Correct result',
    hue_order=[True, False],
    palette={True: "#1f77b4", False: "#d62728"},
    legend=False
)

ax.figure.savefig("Abs_error_add_Llama3b.pdf", format="pdf", dpi=300, bbox_inches="tight")

# %%
# llama 3b-sub
df = pd.read_csv('logs/model_vs_probes_preds_llama3b_sub_210925.csv')
cols = [col for col in df.columns if 'probe' in col]
for col in cols:
    df[col] = abs(df[col] - df['labels'])

df['Correct result'] =  df['model_predictions'] == df['labels']
df[['Correct result'] + cols]

ax = sns.lineplot(
    data=(
        df[['Correct result'] + cols]
        .groupby('Correct result')
        .mean()
        .rename(columns={col: int(col[len('probe_l'):]) for col in cols})
        .reset_index()
        .melt(id_vars=['Correct result'], var_name='layer', value_name='Absolute error')
    ),
    x='layer',
    y='Absolute error',
    hue='Correct result',
    hue_order=[True, False],
    palette={True: "#1f77b4", False: "#d62728"},
    legend=False
)
ax.figure.savefig("Abs_error_sub_Llama3b.pdf", format="pdf", dpi=300, bbox_inches="tight")

# %%
# llama 3b-div
import pandas as pd
import seaborn as sns
# df = pd.read_csv('logs/model_vs_probes_preds_llama3b_div_210925.csv')
df = pd.read_csv('logs/model_vs_probes_preds_llama3b_div_191025.csv')
cols = [col for col in df.columns if 'probe' in col]
for col in cols:
    df[col] = abs(df[col] - df['labels'])

df['Correct result'] =  df['model_predictions'] == df['labels']
df[['Correct result'] + cols]

ax = sns.lineplot(
    data=(
        df[['Correct result'] + cols]
        .groupby('Correct result')
        .mean()
        .rename(columns={col: int(col[len('probe_l'):]) for col in cols})
        .reset_index()
        .melt(id_vars=['Correct result'], var_name='layer', value_name='Absolute error')
    ),
    x='layer',
    y='Absolute error',
    hue='Correct result',
    hue_order=[True, False],
    palette={True: "#1f77b4", False: "#d62728"},
    legend=False
)
ax.figure.savefig("Abs_error_div_Llama3b.pdf", format="pdf", dpi=300, bbox_inches="tight")

# %%
# llama 3b-multi
import pandas as pd
import seaborn as sns

# df = pd.read_csv('logs/model_vs_probes_preds_llama3b_multi_210925_3.csv')
df = pd.read_csv('logs/model_vs_probes_preds_llama3b_multi_101025.csv')
cols = [col for col in df.columns if 'probe' in col]
for col in cols:
    df[col] = abs(df[col] - df['labels'])

df['Correct result'] =  df['model_predictions'] == df['labels']
df[['Correct result'] + cols]

ax = sns.lineplot(
    data=(
        df[['Correct result'] + cols]
        .groupby('Correct result')
        .mean()
        .rename(columns={col: int(col[len('probe_l'):]) for col in cols})
        .reset_index()
        .melt(id_vars=['Correct result'], var_name='layer', value_name='Absolute error')
    ),
    x='layer',
    y='Absolute error',
    hue='Correct result',
    hue_order=[True, False],
    palette={True: "#1f77b4", False: "#d62728"},
    # legend=False
)
ax.figure.savefig("Abs_error_multi_Llama3b.pdf", format="pdf", dpi=300, bbox_inches="tight")

# %%
df[["labels"]*29]
# Out:
#      labels  labels  labels  labels  labels  labels  labels  labels  labels  \
# 0       599     599     599     599     599     599     599     599     599
# 1       792     792     792     792     792     792     792     792     792
# 2       385     385     385     385     385     385     385     385     385
# 3       531     531     531     531     531     531     531     531     531
# 4       552     552     552     552     552     552     552     552     552
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 390     552     552     552     552     552     552     552     552     552
# 391     820     820     820     820     820     820     820     820     820
# 392     820     820     820     820     820     820     820     820     820
# 393     972     972     972     972     972     972     972     972     972
# 394     471     471     471     471     471     471     471     471     471
#
# ...

# %%
df[["probe_l%s" % i for i in range(29)]].mean(axis=0)
# Out:
# probe_l0     624.886076
# probe_l1     624.886076
# probe_l2     624.886076
# probe_l3     624.886076
# probe_l4     624.886076
# probe_l5     624.886076
# probe_l6     624.886076
# probe_l7     624.886076
# probe_l8     624.886076
# probe_l9     624.886076
# probe_l10    624.845570
# probe_l11    624.855696
# probe_l12    624.845570
# probe_l13    624.886076
# probe_l14    260.962025
# probe_l15    424.045570
# probe_l16    382.954430
# probe_l17     67.283544
# probe_l18     46.258228
# probe_l19     24.448101
# probe_l20     37.713924
# probe_l21     22.144304
# probe_l22     18.141772
# probe_l23     16.602532
# probe_l24     19.088608
# probe_l25     22.731646
# probe_l26     13.881013
# probe_l27     15.984810
# probe_l28     30.078481
# dtype: float64

# %%
import pandas as pd
# df = pd.read_csv('logs/model_vs_probes_preds_llama3b_multi_210925.csv')
# df = pd.read_csv('logs/model_vs_probes_preds_llama3b_multi_290925_3.csv')
df = pd.read_csv('logs/model_vs_probes_preds_llama3b_multi_101025.csv')
df['Correct result'] =  df['model_predictions'] == df['labels']

df_breaks = df.copy(deep=True)
num_layers = len([c for c in df.columns if "probe" in c])

df_breaks["probe_l0"] = -1
for col_i in reversed(range(1, num_layers)):
    df["probe_l%s_breaks_result" % col_i] = (df["probe_l%s" % (col_i-1)] == df["Correct result"]) & (df["probe_l%s" % col_i] != df["Correct result"])
    df["probe_l%s_corrects_result" % col_i] = (df["probe_l%s" % (col_i-1)] != df["Correct result"]) & (df["probe_l%s" % col_i] == df["Correct result"])

ax = (df[["probe_l%s_breaks_result" % i for i in range(1, num_layers)]]
    .rename(columns={"probe_l%s_breaks_result" % i: i for i in range(num_layers)}).sum(0) / len(df)).plot()
ax.set_ylabel("Ratio of all")
ax.set_xlabel("Layer")
ax.figure.savefig("per_layer_error_llama3b_multi.pdf", format="pdf", dpi=300, bbox_inches="tight")

# %%
pd.Series([(df["probe_l%s_corrects_result" % i].sum() - df["probe_l%s_breaks_result" % i].sum()) for i in range(1, num_layers)]).plot()
# Out:
# <Axes: >

# %%
df = pd.read_csv('logs/model_vs_probes_preds_llama3b_add_220925.csv')
df['Correct result'] =  df['model_predictions'] == df['labels']

df_breaks = df.copy(deep=True)
num_layers = len([c for c in df.columns if "probe" in c])

df_breaks["probe_l0"] = -1
for col_i in reversed(range(1, num_layers)):
    df["probe_l%s_breaks_result" % col_i] = (df["probe_l%s" % (col_i-1)] == df["Correct result"]) & (df["probe_l%s" % col_i] != df["Correct result"])
    df["probe_l%s_corrects_result" % col_i] = (df["probe_l%s" % (col_i-1)] != df["Correct result"]) & (df["probe_l%s" % col_i] == df["Correct result"])

ax = (df[["probe_l%s_breaks_result" % i for i in range(1, num_layers)]]
    .rename(columns={"probe_l%s_breaks_result" % i: i for i in range(num_layers)}).sum(0) / len(df)).plot()
ax.set_ylabel("Ratio of all")
ax.set_xlabel("Layer")
ax.figure.savefig("per_layer_error_llama3b_add.pdf", format="pdf", dpi=300, bbox_inches="tight")

# %%
df = pd.read_csv('logs/model_vs_probes_preds_llama3b_sub_210925.csv')
df['Correct result'] =  df['model_predictions'] == df['labels']

df_breaks = df.copy(deep=True)
num_layers = len([c for c in df.columns if "probe" in c])

df_breaks["probe_l0"] = -1
for col_i in reversed(range(1, num_layers)):
    df["probe_l%s_breaks_result" % col_i] = (df["probe_l%s" % (col_i-1)] == df["Correct result"]) & (df["probe_l%s" % col_i] != df["Correct result"])
    df["probe_l%s_corrects_result" % col_i] = (df["probe_l%s" % (col_i-1)] != df["Correct result"]) & (df["probe_l%s" % col_i] == df["Correct result"])

ax = (df[["probe_l%s_breaks_result" % i for i in range(1, num_layers)]]
    .rename(columns={"probe_l%s_breaks_result" % i: i for i in range(num_layers)}).sum(0) / len(df)).plot()
ax.set_ylabel("Ratio of all")
ax.set_xlabel("Layer")
ax.figure.savefig("per_layer_error_llama3b_sub.pdf", format="pdf", dpi=300, bbox_inches="tight")

# %%
pd.Series([(df["probe_l%s_corrects_result" % i].sum() - df["probe_l%s_breaks_result" % i].sum()) for i in range(1, num_layers)]).plot()
# Out:
# <Axes: >

# %%
import pandas as pd
df = pd.read_csv('logs/model_vs_probes_preds_llama3b_div_210925.csv')
# df = pd.read_csv('logs/model_vs_probes_preds_llama3b_div_191025.csv')
df['Correct result'] =  df['model_predictions'] == df['labels']

df_breaks = df.copy(deep=True)
num_layers = len([c for c in df.columns if "probe" in c])

df_breaks["probe_l0"] = -1
for col_i in reversed(range(1, num_layers)):
    df["probe_l%s_breaks_result" % col_i] = (df["probe_l%s" % (col_i-1)] == df["Correct result"]) & (df["probe_l%s" % col_i] != df["Correct result"])
    df["probe_l%s_corrects_result" % col_i] = (df["probe_l%s" % (col_i-1)] != df["Correct result"]) & (df["probe_l%s" % col_i] == df["Correct result"])

ax = (df[["probe_l%s_breaks_result" % i for i in range(1, num_layers)]]
    .rename(columns={"probe_l%s_breaks_result" % i: i for i in range(num_layers)}).sum(0) / len(df)).plot()
ax.set_ylabel("Ratio of all")
ax.set_xlabel("Layer")
ax.figure.savefig("per_layer_error_llama3b_div.pdf", format="pdf", dpi=300, bbox_inches="tight")

# %%
import pandas as pd
df = pd.read_csv('logs/model_vs_probes_preds_llama3b_div_210925.csv')
# df = pd.read_csv('logs/model_vs_probes_preds_llama3b_div_191025.csv')
df['Correct result'] =  df['model_predictions'] == df['labels']

df_breaks = df.copy(deep=True)
num_layers = len([c for c in df.columns if "probe" in c])

df_breaks["probe_l0"] = -1
for col_i in reversed(range(1, num_layers)):
    df["probe_l%s_breaks_result" % col_i] = (df["probe_l%s" % (col_i-1)] == df["Correct result"]) & (df["probe_l%s" % col_i] != df["Correct result"])
    df["probe_l%s_corrects_result" % col_i] = (df["probe_l%s" % (col_i-1)] != df["Correct result"]) & (df["probe_l%s" % col_i] == df["Correct result"])

model_acc_without_lx = pd.Series([0, 0.0, 0.005988024175167084, 0.9401198029518127, 0.8203592896461487, 0.946107804775238, 0.8982036113739014, 0.9101796746253967, 0.8922156095504761, 0.9640718698501587, 0.9401198029518127, 0.9700599312782288, 0.7065868377685547, 0.9041916728019714, 0.6946108341217041, 0.34131738543510437, 0.6946108341217041, 0.34730541706085205, 0.8143712878227234, 0.7664670944213867, 0.832335352897644, 0.8862276077270508, 0.8443114161491394, 0.916167676448822, 0.9640718698501587, 0.946107804775238, 0.9281437397003174, 0.8143712878227234, 0.8622754812240601])
model_acc_without_lx = (model_acc_without_lx - 0.9401) / 0.9401
model_acc_without_lx = model_acc_without_lx.apply(lambda x: 0 if x < 0 else x)


ax = (df[["probe_l%s_breaks_result" % i for i in range(1, num_layers)]]
    .rename(columns={"probe_l%s_breaks_result" % i: i for i in range(num_layers)}).sum(0) / len(df)).plot()

ax = model_acc_without_lx.plot(ax=ax)

# ax.set_ylabel("% of result breakages / perf change when dropped")
ax.set_xlabel("Layer")
ax.legend(["Ratio of broken predictions on L", "Change in performance when L dropped"])
ax.figure.savefig("per_layer_error_llama3b_div.pdf", format="pdf", dpi=300, bbox_inches="tight")

# %%
df.columns
# Out:
# Index(['probe_l28', 'probe_l27', 'probe_l26', 'probe_l25', 'probe_l24',
#        'probe_l23', 'probe_l22', 'probe_l21', 'probe_l20', 'probe_l19',
#        'probe_l18', 'probe_l17', 'probe_l16', 'probe_l15', 'probe_l14',
#        'probe_l13', 'probe_l12', 'probe_l11', 'probe_l10', 'probe_l9',
#        'probe_l8', 'probe_l7', 'probe_l6', 'probe_l5', 'probe_l4', 'probe_l3',
#        'probe_l2', 'probe_l1', 'probe_l0', 'model_predictions', 'inputs',
#        'labels', 'Correct result', 'probe_l28_breaks_result',
#        'probe_l28_corrects_result', 'probe_l27_breaks_result',
#        'probe_l27_corrects_result', 'probe_l26_breaks_result',
#        'probe_l26_corrects_result', 'probe_l25_breaks_result',
#        'probe_l25_corrects_result', 'probe_l24_breaks_result',
#        'probe_l24_corrects_result', 'probe_l23_breaks_result',
#        'probe_l23_corrects_result', 'probe_l22_breaks_result',
#        'probe_l22_corrects_result', 'probe_l21_breaks_result',
# ...

# %%
len((df[["probe_l%s_breaks_result" % i for i in range(1, num_layers)]]
    .rename(columns={"probe_l%s_breaks_result" % i: i for i in range(num_layers)}).sum(0) / len(df)))
# Out:
# 28

# %%
pd.Series([(df["probe_l%s_corrects_result" % i].sum() - df["probe_l%s_breaks_result" % i].sum()) / len(df) for i in range(1, num_layers)]).plot(grid=True)
# Out:
# <Axes: >
